# %% [markdown]
# <a href="https://colab.research.google.com/github/Chen-Wi-Ki/Colab-DogCat-CNN/blob/main/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 驗證以下感測器飄移落差之問題

# %% [markdown]
# ![SensorNumber.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 其中15:27與15:19底下有做記號,這是被多人體感認為飄移可能比其他更嚴重的。

# %% [markdown]
# [機械手臂測試影片](https://drive.google.com/file/d/1NzAo1iacbFc-byWdNFRZfZxZmeTYtNr4/view?usp=sharing)
